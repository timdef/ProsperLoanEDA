# %% [markdown]
# # Exploration Outline / Guide
#
# ## Univariate Exploration
#
# + Read Data
# + Load Libraries
# + Dimension and Structure
# + Are Listing Keys Unique? Surprisingly No
#   + TODO: Find way to clean listing keys.  Multiple Prosper Scores (should also verify programmatically)
# + Summary of df
# + Term
# + LoanStatus
#   + Plot distribution of LoanStatus 'Past Due'
#   + Examine 'Canceled' Loans
#   + Add LoanStatus.Simple and Plot it
# + Borrower APR
# + Borrower Rate
# + Estimated Effective Yield
# + ProsperScore
# + Listing Category
#   + CLEANING: create listingToCharacter, new column ListingCategory
# + Occupation
# + Employment Status
# + Employment Status Duration
# + Credit Score
#   + TODO: Eliminate putting columns into new variables
#   + TODO: Find range between upper and lower scores for each record. Perhaps mutate into feasible average.
#   + TODO: see Upper and Lower In Same Plot by color
# + Lender Yield
# + Estimated Effective Yield
#   + TODO: remove duplicate section
# + Income Range
#   + CLEANING: correcting factors
#   + TODO: investigate loans make to people with 0 income
# + Income Verifiable
#   + TODO: consider moving Range w dodged Verifiable here
# + Monthly Loan Payment
# + Loan Original Amount
# + Percent Funded
# + Number of Investors
#   + TODO: make sure this is plotted against size of loan
# +  NOTE: Multivariate Exploration actually starts here, mustve begun before I separted files.

# %% [markdown]
# ## Multivariate Exploration
#
# + Term and APR
# + Term and Lender Yield
# + Term and Estimated Effective Yield
#   + Investigate Negative Estimated Effective Yield
# + Term and IncomeRange
#   + Range factors fixed here again?
#   + TODO: make sure IncomeRange factors fixed only once
#   + TODO: fix state used in these faceted bar plots
# Note: End of file UnivariateExploration

# %% [markdown]
# ## BivariateExploration (file)
#
# + Read CSV, load libraries
#   + Do we need plyr? Can we just loat Tidyverse?
# + Frequency of Term by Income Range
#   + CLEANING: Adjust IncomeRange factors
#   + TODO: make sure not adjusting this factor multiple times
# + Term and LoanStatus
# + BorrowerAPR and Term
# + Estimated Effective Yield and Term
# + Original Loan Amount by Term
# + Loan Status and Borrower APR
# + Loan Status and Listing Category
#   + CLEANING: listing numeric to character
#   + TODO: make sure dont duplicate this cleaning
# + Loan Status vs IncomeRange
# + Borrower APR vs Credit Score Range
#   + explored abberent, low credit scores
#   + TODO: move these to the univariate exploration
# + Borrower APR vs Listing Category
# + Borrower APR vs Occupation
# + Borrower APR vs Employment Duration
# + Prosper Score vs Borrower Rate
# + Prosper Score vs Borrower APR
# + Prosper Score vs Occupation
# + Proser Score vs Employment Status
#   + CLEANING: groupy employment status types
# + Prosper Score vs Credit Range
# + Listing Category and Occupation
# + Listing Category and Employment Status
# + Borrower State and Occupation
#   + NOTE: could probably lose this one
# + Borrower State vs Income Range
# + Credit Score vs Income Range
# + Income Range and Income Range Verified
# + Income Range and Monthly Loan Payment
# + Income Range and Loan Original Amount
#
# OK - so there are measurements of certain types of things that can be grouped together.
# I think these are:
# + Rates
#   + Lender
#   + Borrower
# + Borrower Worthiness
# + Other Borrower Attributes

# %% [markdown]
# ### Other todo's:
# + correct dataframe names
